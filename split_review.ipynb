# %%
with open('H:/Data/review_POS.txt' ,"r", encoding = "UTF-8") as f:
    review = f.readlines()
    review[0:2]
#     review = review.split('\n')

# %%
review[0:50]
# Out:
# ["[('I', 'PRP'), ('love', 'VBP'), ('the', 'DT'), ('old', 'JJ'), ('school', 'NN'), ('style', 'NN'), ('and', 'CC'), ('these', 'DT'), ('sneakers', 'NNS'), ('are', 'VBP'), ('so', 'RB'), ('comfortable', 'JJ')]\n",
#  "[('A', 'DT'), ('true', 'JJ'), ('classic', 'NN'), ('for', 'IN'), ('the', 'DT'), ('fans', 'NNS'), ('of', 'IN'), ('sneakers', 'NNS'), ('and', 'CC'), ('culture', 'NN'), ('Very', 'NNP'), ('nice', 'RB'), ('made', 'VBD'), ('and', 'CC'), ('the', 'DT'), ('materials', 'NNS'), ('are', 'VBP'), ('pretty', 'RB'), ('good', 'JJ'), ('too', 'RB')]\n",
#  "[('They', 'PRP'), ('were', 'VBD'), ('sneakers', 'NNS'), ('I', 'PRP'), ('wore', 'VBP'), ('when', 'WRB'), ('I', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('kid', 'NN'), ('so', 'RB'), ('I', 'PRP'), ('always', 'RB'), ('like', 'IN'), ('going', 'VBG'), ('retro', 'NN'), ('when', 'WRB'), ('sneakers', 'NNS'), ('r', 'VBP'), ('rereleased', 'VBN')]\n",
# ...
