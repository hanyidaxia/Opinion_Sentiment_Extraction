# %%
import selenium
import time
from selenium import webdriver
from bs4 import BeautifulSoup as BS
from selenium.webdriver.chrome.options import Options
import sys
import pickle
import pandas as pd

# %%
page_range = ["",
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=40", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=80", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=120", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=160", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=200", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=240", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=280", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=320", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=360", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=400", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=440", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=480", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=520", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=560", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=600", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=640", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=680", 
              "#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=720"]

# %%
print(len(page_range))
# Out:
# 19

# %%
def get_links (i):
#     options = Options()
#     options.add_argument("start-maximized")
    browser = webdriver.Firefox()
    browser_name = "https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual" + i
    print(browser_name)
    browser.get(browser_name)
#     browser.delete_all_cookies()
    time.sleep(30)
    bs_obj = BS(browser.page_source, "html.parser")
    namelist = bs_obj.findAll("div", {"product-card"})
    links = []
    for g in namelist:
        links.append(g.find("a").attrs["href"])
#     print(links)
    browser.quit()    
    return links

# %%
all_links = []
for i in page_range:
    link = get_links(i)
    all_links.append(link)
#     time.sleep(2)
# Out:
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=40
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=80
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=120
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=160
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=200
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=240
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=280
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=320
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=360
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=400
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=440
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=480
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=520
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=560
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=600
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=640
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=680
# https://www.finishline.com/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual#/store/men/shoes/casual/_/N-1q3xsyk?mnid=men_shoes_casual&No=720

# %%
print(all_links[3])
# Out:
# ['/store/product/mens-adidas-nmd-runner-r1-casual-shoes/prod2763986?styleId=B42200&colorId=BLK', '/store/product/mens-champion-court-classic-casual-shoes/prod2784682?styleId=CMS10009&colorId=001', '/store/product/mens-champion-3-on-3-casual-shoes/prod2784681?styleId=CMS10016&colorId=002', '/store/product/mens-nike-cortez-basic-casual-shoes/prod2792617?styleId=CI9873&colorId=400', '/store/product/mens-nike-air-force-1-07-3-casual-shoes/prod2785277?styleId=AO2423&colorId=101', '/store/product/mens-converse-courlandt-casual-shoes/prod2783954?styleId=163201C&colorId=GLD', '/store/product/mens-adidas-originals-yung-96-casual-shoes/prod2785194?styleId=F35017&colorId=NVY', '/store/product/mens-nike-react-presto-running-shoes/prod2787433?styleId=AV2605&colorId=200', '/store/product/mens-nike-shox-r4-running-shoes/prod741979?styleId=104265&colorId=044', '/store/product/mens-fila-ray-tracer-90s-qs-casual-shoes/prod2787702?styleId=1RM00645&colorId=404', '/store/product/mens-k-swiss-court-casper-casual-shoes/prod2761102?styleId=5586A&colorId=002', '/store/product/mens-nike-air-huarache-run-casual-shoes/prod1360199?styleId=318429&colorId=111', '/store/product/mens-adidas-stan-smith-vulc-casual-shoes/prod774579?styleId=EE6987&colorId=100', '/store/product/mens-puma-electron-street-trainer-casual-shoes/prod2780134?styleId=367309&colorId=BLK', '/store/product/mens-jordan-89-racer-running-shoes/prod2785509?styleId=AQ3747&colorId=006', '/store/product/mens-lacoste-fraisier-leather-slide-sandals/prod2786303?styleId=735CAM01&colorId=1V7', '/store/product/mens-snkr-project-park-avenue-casual-shoes/prod2780767?styleId=SNKR1807&colorId=020', '/store/product/mens-nike-air-vapormax-2019-premium-running-shoes/prod2785457?styleId=AT6810&colorId=100', '/store/product/mens-nike-air-force-1-high-07-lv8-casual-shoes/prod2771046?styleId=CJ0525&colorId=100', '/store/product/mens-nike-air-max-97-casual-shoes/prod2770629?styleId=921826&colorId=008', '/store/product/mens-nike-benassi-jdi-print-slide-sandals/prod800383?styleId=631261&colorId=102', '/store/product/mens-nike-huarache-edge-txt-running-shoes/prod2785463?styleId=AO1697&colorId=003', '/store/product/mens-nike-benassi-jdi-print-slide-sandals/prod800383?styleId=631261&colorId=406', '/store/product/mens-nike-air-max-command-mesh-casual-shoes/prod2785485?styleId=629993&colorId=039', '/store/product/mens-nike-air-max-ltd-3-casual-shoes/prod795091?styleId=BV1171&colorId=100', '/store/product/mens-champion-ipo-jock-slide-sandals/prod2784701?styleId=CM1001&colorId=45M', '/store/product/mens-nike-air-force-1-low-casual-shoes/prod795980?styleId=315122&colorId=001', '/store/product/mens-nike-air-vapormax-flyknit-2-running-shoes/prod2772861?styleId=942842&colorId=015', '/store/product/mens-champion-93eighteen-casual-shoes/prod2780751?styleId=CMS10013&colorId=001', '/store/product/mens-snkr-project-crosby-casual-shoes/prod2784800?styleId=SNKR1814&colorId=270', '/store/product/mens-adidas-i-5923-runner-casual-shoes/prod902025?styleId=D97213&colorId=BKY', '/store/product/mens-adidas-originals-nite-jogger-casual-shoes/prod2787166?styleId=DB3361&colorId=033', '/store/product/mens-nike-air-huarache-run-casual-shoes/prod1360199?styleId=318429&colorId=660', '/store/product/mens-fila-boveasorus-99-casual-shoes/prod2785932?styleId=1RM00576&colorId=319', '/store/product/mens-nike-cortez-basic-floral-casual-shoes/prod2785328?styleId=BV6067&colorId=001', '/store/product/mens-nike-air-max-720-running-shoes/prod2785386?styleId=AO2924&colorId=002', '/store/product/mens-converse-courlandt-casual-shoes/prod2783954?styleId=162594C&colorId=BLU', '/store/product/mens-nike-air-vapormax-2019-running-shoes/prod2785452?styleId=AR6631&colorId=300', '/store/product/mens-nike-air-max-97-casual-shoes/prod2770629?styleId=921826&colorId=201', '/store/product/mens-jordan-89-racer-running-shoes/prod2785509?styleId=AQ3747&colorId=001']

# %%
casual_links = all_links

# %%
running_page_range = ["",
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=40", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=80", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=120", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=160", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=200", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=240", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=280", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=320", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=360", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=400", 
              "#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=440"]

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
def get_running (i):
    browser = webdriver.Firefox()
    browser_name = "https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running" + i
    print(browser_name)
    browser.get(str(browser_name))
    time.sleep(45)
    bs_obj = BS(browser.page_source, "html.parser")
    namelist = bs_obj.findAll("div", {"product-card"})
    links = []
    for g in namelist:
        links.append(g.find("a").attrs["href"])
    browser.quit()
    return links

# %%
Running_links = []
for i in running_page_range:
    link = get_running(i)
    Running_links.append(link)
#     time.sleep(2)
# Out:
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=40
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=80
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=120
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=160
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=200
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=240
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=280
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=320
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=360
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=400
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running&No=440

# %%
len(Running_links)
# Out:
# 12

# %%
basketball_page_range = ["",
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=40", 
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=80", 
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=120", 
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=160", 
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=200", 
              "#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=240"]

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
def get_basketball (i):
    browser = webdriver.Firefox()
    browser_name = "https://www.finishline.com/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball" + i
    print(browser_name)
    browser.get(str(browser_name))
    time.sleep(45)
    bs_obj = BS(browser.page_source, "html.parser")
    namelist = bs_obj.findAll("div", {"product-card"})
    links = []
    for g in namelist:
        links.append(g.find("a").attrs["href"])
    browser.quit()
    return links

# %%
Basketball_links = []
for i in basketball_page_range:
    link = get_running(i)
    Basketball_links.append(link)
#     time.sleep(2)
# Out:
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=40
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=80
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=120
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=160
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=200
# https://www.finishline.com/store/men/shoes/running/_/N-57cgax?mnid=men_shoes_running#/store/men/shoes/basketball/_/N-3z3fil?mnid=men_shoes_basketball&No=240

# %%
training_page_range = ["",
              "#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=40", 
              "#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=80", 
              "#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=120", 
              "#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=160"]

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
def get_training (i):
    browser = webdriver.Firefox()
    browser_name = "https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym" + i
    print(browser_name)
    browser.get(str(browser_name))
    time.sleep(30)
    bs_obj = BS(browser.page_source, "html.parser")
    namelist = bs_obj.findAll("div", {"product-card"})
    links = []
    for g in namelist:
        links.append(g.find("a").attrs["href"])
    browser.quit
    return links

# %%
Training_links = []
for i in training_page_range:
    link = get_training(i)
    Training_links.append(link)
#     time.sleep(2)
# Out:
# https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym
# https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=40
# https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=80
# https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=120
# https://www.finishline.com/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym#/store/men/shoes/training-gym/_/N-kadepn?mnid=men_shoes_traininggym&No=160

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
def get_boots ():
    browser = webdriver.Firefox()
    browser_name = "https://www.finishline.com/store/men/shoes/boots/_/N-1psj4ir?mnid=men_shoes_boots"
    print(browser_name)
    browser.get(str(browser_name))
    time.sleep(45)
    bs_obj = BS(browser.page_source, "html.parser")
    namelist = bs_obj.findAll("div", {"product-card"})
    links = []
    for g in namelist:
        links.append(g.find("a").attrs["href"])
    browser.quit()
    return links

# %%
boots_links = []

link = get_boots()
boots_links.append(link)
#     time.sleep(2)
# Out:
# https://www.finishline.com/store/men/shoes/boots/_/N-1psj4ir?mnid=men_shoes_boots

# %%
print(len(casual_links), len(Running_links), len(Basketball_links), len(Training_links), len(boots_links))
# Out:
# 19 12 7 5 1

# %%
# print(casual_links[0][0])

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
# browser_name = "https://www.finishline.com"+casual_links[0][0]
# print(browser_name)
# browser.get(browser_name)
# time.sleep(45)
# browser.find_element_by_name("icon icon-chevron-right").click()

# %%
# options = Options()
# options.add_argument("start-maximized")
# browser = webdriver.Chrome(chrome_options = options)
# browser_name = "https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_" + "Air_Jordan_1_Mid_Retro_Basketball_Shoes/" + "reviews.djs?format=html&page=9&scrollToTop=true"
# print(browser_name)
# browser.get(browser_name)
# time.sleep(20)
# bs_obj = BS(browser.page_source, "html.parser")
# reviews = bs_obj.findAll("span", {"class": "BVRRReviewText"})

# %%
# options = Options()/

# %%
# for i in reviews:
#     print(i.findAll("li"))

# %%
# print(reviews, rate_num)
# for i in reviews:
#     print(i.find_all(["li", "BVRRCustomReviewCountNumber"]))
# for j in rate_num:
#     print(j.find_all)

# %%
all_product = casual_links+ Running_links+ Basketball_links+ Training_links+ boots_links

# %%
len(all_product)
# Out:
# 44

# %%
print(all_product)
# Out:
# [['/store/product/mens-nike-air-force-1-low-casual-shoes/prod795980?styleId=315122&colorId=111', '/store/product/mens-nike-air-max-97-casual-shoes/prod2770629?styleId=921826&colorId=101', '/store/product/mens-air-jordan-retro-1-low-basketball-shoes/prod797157?styleId=553558&colorId=116', '/store/product/mens-nike-react-presto-running-shoes/prod2787433?styleId=AV2605&colorId=700', '/store/product/mens-nike-shox-nz-running-shoes/prod792244?styleId=378341&colorId=059', '/store/product/mens-air-jordan-1-mid-retro-basketball-shoes/prod1370657?styleId=554724&colorId=119', '/store/product/mens-nike-air-vapormax-flyknit-3-running-shoes/prod2787099?styleId=AJ6900&colorId=004', '/store/product/mens-nike-react-presto-running-shoes/prod2787433?styleId=AV2605&colorId=100', '/store/product/mens-nike-air-vapormax-flyknit-3-running-shoes/prod2787099?styleId=AJ6900&colorId=102', '/store/product/mens-air-jordan-retro-1-low-basketball-shoes/prod797157?styleId=553558&colorId=112', '/store/product/mens-nike-air-max-95-og-casual-shoes/prod2779738?styleId=CD7495&colorId=101', '/store/product/mens-nike-air-max-97-nd-casual-shoes/prod2785494?styleId=BQ9130&colorId=500', '/store/product/mens-nike-air-max-90-essential-casual-shoes/prod2776645?styleId=AJ1285&colorId=602', '/store/product/mens-champion-ipo-repeat-slide-sandals/prod2780707?styleId=CM100079&colorId=001', '/store/product/mens-jordan-hydro-4-retro-slide-sandals/prod1500186?styleId=532225&colorId=006', '/store/product/mens-adidas-nmd-runner-r1-casual-shoes/prod2763986?styleId=BD7754&colorId=001', '/store/product/mens-nike-react-presto-running-shoes/prod2787433?styleId=AV2605&colorId=002', '/store/product/mens-nike-air-max-90-leather-casual-shoes/prod1260016?styleId=302519&colorId=113', '/store/product/mens-nike-air-vapormax-flyknit-2-running-shoes/prod2772861?styleId=942842&colorId=016', '/store/product/mens-nike-air-huarache-run-casual-shoes/prod1360199?styleId=318429&colorId=003', '/store/product/mens-nike-air-max-270-casual-shoes/prod2770900?styleId=AH8050&colorId=005', '/store/product/mens-adidas-nmd-runner-r1-casual-shoes/prod2763986?styleId=BD7745&colorId=001', '/store/product/mens-air-jordan-1-mid-retro-basketball-shoes/prod1370657?styleId=554724&colorId=116', '/store/product/mens-nike-air-vapormax-plus-running-shoes/prod2770771?styleId=924453&colorId=018', '/store/product/mens-nike-air-max-95-casual-shoes/prod765900?styleId=609048&colorId=092', '/store/product/mens-adidas-nmd-r1-stlt-primeknit-casual-shoes/prod270001?styleId=D96635&colorId=WWG', '/store/product/mens-nike-shox-nz-running-shoes/prod792244?styleId=378341&colorId=110', '/store/product/mens-nike-air-max-97-casual-shoes/prod2770629?styleId=921826&colorId=001', '/store/product/mens-adidas-swift-run-running-shoes/prod2761175?styleId=DB3603&colorId=BKG', '/store/product/mens-nike-zoom-2k-casual-shoes/prod2785246?styleId=AO0269&colorId=100', '/store/product/mens-nike-m2k-tekno-casual-shoes/prod2781154?styleId=AV4789&colorId=002', '/store/product/mens-nike-huarache-edge-leather-running-shoes/prod2785462?styleId=AV3598&colorId=002', '/store/product/mens-reebok-classics-rivyx-ripple-casual-shoes/prod2786729?styleId=DV6619&colorId=WHT', '/store/product/mens-nike-huarache-edge-txt-running-shoes/prod2785463?styleId=AO1697&colorId=001', '/store/product/mens-nike-m2k-tekno-casual-shoes/prod2781154?styleId=AV4789&colorId=101', '/store/product/mens-adidas-originals-pod-s31-casual-shoes/prod2778724?styleId=G27906&colorId=GRY', '/store/product/mens-adidas-originals-xplr-casual-shoes/prod1510031?styleId=B37932&colorId=GRN', '/store/product/mens-nike-air-max-90-essential-casual-shoes/prod2776645?styleId=AJ1285&colorId=016', '/store/product/mens-nike-benassi-jdi-slide-sandals/prod782575?styleId=343880&colorId=090', '/store/product/mens-nike-m2k-tekno-casual-shoes/prod2781154?styleId=AV4789&colorId=004'], ['/store/product/mens-nike-huarache-edge-txt-running-shoes/prod2785463?styleId=AO1697&colorId=100', '/store/product/mens-jordan-89-racer-runn ...

# %%
with open("J:/product_names.txt", "r") as x:
    all_product = x.read().splitlines()

# %%
for i in all_product:
    i = i.strip('\n')

# %%
from collections import Counter
print(Counter(all_product))
# Out:
# Counter({'/store/product/mens-reebok-classic-leather-gum-casual-shoes/prod2910001?styleId=49797&colorId=WHT': 1, '/store/product/mens-adidas-originals-pod-s31-casual-shoes/prod2778724?styleId=G27906&colorId=GRY': 1, '/store/product/mens-lacoste-chaymon-casual-shoes/prod802141?styleId=CHAYMON&colorId=95K': 1, '/store/product/mens-nike-shox-nz-running-shoes/prod792244?styleId=378341&colorId=110': 1, '/store/product/mens-nike-air-force-270-utility-off-court-shoes/prod2783828?styleId=AQ0572&colorId=001': 1, '/store/product/mens-adidas-originals-xplr-casual-shoes/prod1510031?styleId=B37930&colorId=KHA': 1, '/store/product/unisex-converse-chuck-taylor-all-star-70-high-top-casual-shoes/prod2785695?styleId=163367C&colorId=671': 1, '/store/product/mens-nike-free-rn-flyknit-2018-running-shoes/prod2770896?styleId=942838&colorId=002': 1, '/store/product/mens-adidas-upath-run-running-shoes/prod2786786?styleId=G27637&colorId=WHT': 1, '/store/product/mens-air-jordan-executive-off-court-shoes/prod800295?styleId=820240&colorId=001': 1, '/store/product/mens-nike-huarache-edge-txt-running-shoes/prod2785463?styleId=CI9870&colorId=001': 1, '/store/product/mens-timberland-philadelphia-76ers-nba-field-boots/prod2786411?styleId=A24AY&colorId=001': 1, '/store/product/mens-air-jordan-why-not-zer02-basketball-shoes/prod2785906?styleId=AO6219&colorId=001': 1, '/store/product/mens-fila-ray-tracer-casual-shoes/prod2785958?styleId=1RM00586&colorId=051': 1, '/store/product/mens-nike-react-element-55-casual-shoes/prod2782229?styleId=CJ0782&colorId=100': 1, '/store/product/mens-reebok-dmx-series-1600-casual-shoes/prod2783847?styleId=CN7736&colorId=GRY': 1, '/store/product/mens-nike-air-force-1-07-lv8-style-casual-shoes/prod2783297?styleId=AQ0117&colorId=800': 1, '/store/product/mens-adidas-originals-pod-s31-casual-shoes/prod2778724?styleId=B37363&colorId=GRY': 1, '/store/product/mens-nike-air-max-90-essential-casual-shoes/prod2776645?styleId=AJ1285&colorId=022': 1, '/store/product/mens-adidas-zx-flux-casual-shoes/prod1300435?styleId=DB3299&colorId=001': 1, '/store/product/mens-adidas-ultraboost-st-running-shoes/prod2770421?styleId=B37694&colorId=BWG': 1, '/store/product/mens-under-armour-hovr-phantom-se-running-shoes/prod2785117?styleId=3021587&colorId=600': 1, '/store/product/mens-adidas-pro-vision-select-player-edition-basketball-shoes/prod2787336?styleId=EE6867&colorId=RBL': 1, '/store/product/mens-nike-kawa-slide-sandals/prod1150058?styleId=832528&colorId=001': 1, '/store/product/mens-nike-benassi-jdi-slide-sandals/prod782575?styleId=343880&colorId=001': 1, '/store/product/mens-nike-free-rn-2018-running-shoes/prod2770891?styleId=942836&colorId=002': 1, '/store/product/mens-puma-cell-venom-running-shoes/prod2791417?styleId=37041701&colorId=001': 1, '/store/product/mens-adidas-questar-trail-running-shoes/prod2788631?styleId=F35004&colorId=097': 1, '/store/product/mens-nike-air-max-270-casual-shoes/prod2770900?styleId=CJ0520&colorId=001': 1, '/store/product/mens-nike-classic-cortez-premium-casual-shoes/prod2783209?styleId=807480&colorId=700': 1, '/store/product/mens-under-armour-hovr-slk-evo-running-shoes/prod2785121?styleId=3021457&colorId=602': 1, '/store/product/mens-air-jordan-retro-1-low-basketball-shoes/prod797157?styleId=553558&colorId=127': 1, '/store/product/mens-nike-air-max-270-se-reflective-casual-shoes/prod2784603?styleId=BQ6525&colorId=001': 1, '/store/product/mens-adidas-duramo-9-running-shoes/prod2778366?styleId=B96578&colorId=BLK': 1, '/store/product/mens-air-jordan-1-mid-retro-basketball-shoes/prod1370657?styleId=554724&colorId=061': 1, '/store/product/mens-nike-odyssey-react-flyknit-2-running-shoes/prod2785249?styleId=AH1015&colorId=003': 1, '/store/product/mens-nike-cortez-basic-floral-casual-shoes/prod2785328?styleId=BV6067&colorId=001': 1, '/store/product/mens-new-balance-990-v4-mid-running-shoes/prod2768805?styleId=MO990GR4&colorId=GRY': 1, '/store/product/mens-nike-vapormax-gliese-casual-shoes/prod2785003?styleId=AO2445&colorId=001': 1 ...

# %%
import numpy as np
# np.shape(all_product)
all_set = set(all_product)
len(all_set)
all_product = list(all_set)
len(all_product)
# Out:
# 1170

# %%
# product_name_description = {}
with open ("J:/descriptions.txt", 'a', encoding='utf-8') as f:
    for name in [all_product]:
        for url in name:
            options = Options()
            options.add_argument("start-maximized")
            browser = webdriver.Chrome(chrome_options = options)
            print(url)
            product_name = url.split('/')[3]
            browser_name = "https://www.finishline.com" + url
            browser.get(browser_name)
            time.sleep(30)
            bs_obj = BS(browser.page_source.encode('utf-8', 'ignore'), "html.parser")
            description = bs_obj.findAll("div", {"class":"column small-12"})  
            for i in description:
        #       print(i.find_all("li"))
#                 product_name_description[product_name] = [i.find_all("li")]
                details = "".join(i.stripped_strings)
                f.write(product_name + "===" + repr(details))
                f.write('\n')
                f.flush()
                browser.quit()

# %%
# with open("J:/test_1.txt", "w", encoding='utf-8') as lk:
#     options = Options()
#     options.add_argument("start-maximized")
#     browser = webdriver.Chrome(chrome_options = options)
#     url = '/store/product/mens-jordan-hydro-4-retro-slide-sandals/prod1500186?styleId=532225&colorId=006'
#     product_name = url.split('/')[3]
#     browser_name = "https://www.finishline.com" + url
#     browser.get(browser_name)
#     time.sleep(20)
#     bs_obj = BS(browser.page_source.encode('utf-8', 'ignore'), "html.parser")
#     description = bs_obj.findAll("div", {"class":"column small-12"})  
#     for i in description:
#             #       print(i.find_all("li"))
#     #                 product_name_description[product_name] = [i.find_all("li")]
#         details = "".join(i.stripped_strings)
#         lk.write(product_name + "===" + repr(details))

# %%
# with open("J:/test_1.txt", "w") as lk:
#     print(details, product_name)
#     lk.write(repr(details)+ "===" + product_name)

# %%
# len(product_name_description)

# %%
# df = pd.DataFrame.from_dict(product_name_description, orient="index")
# df.to_csv('J:/product_descriptions_2.csv')

# %%
# import sys
# sys.setrecursionlimit(100000000)
# import numpy as np
# np.save("d1.npy", product_name_description)
# d2=np.load("d1.npy")

# %%
# import pickle

# with open('filename.pickle', 'wb') as handle:
#     pickle.dump(product_name_description, handle, protocol=pickle.HIGHEST_PROTOCOL)

# # with open('filename.pickle', 'rb') as handle:
# #     b = pickle.load(handle)

# %%
# for i in description:
#     print(i.find_all("li"))

# %%
# with open ("J:/descriptions.txt", "w") as f:
#     for i in product_name_description:
#         f.write(i)
#         f.write('\n')

# %%
# len(all_product)

# %%
# with open("J:/product_names_with_douhao.txt", "w") as p:
#     for i in all_product:
#         for j in i:
#             p.write(j + ",")
#             p.write('\n')
all_product[2]
# Out:
# '/store/product/mens-lacoste-chaymon-casual-shoes/prod802141?styleId=CHAYMON&colorId=95K'

# %%
product_name = []
for i in all_product:
    i = i.split('/')[3]
    product_name.append(i)
    
product_name[0]
# Out:
# 'mens-reebok-classic-leather-gum-casual-shoes'

# %%
import string

# %%
# for j in product_name:
#     string.capwords(j)

# %%
product_new_name = []
for j in product_name:
    j = j.replace("-", " ")
    j = (string.capwords(j))
    j = j.replace(" ", "_")
    j = j.replace("Mens_", "")
    product_new_name.append(j)
    
product_new_name[0: 5]
# Out:
# ['Reebok_Classic_Leather_Gum_Casual_Shoes',
#  'Adidas_Originals_Pod_S31_Casual_Shoes',
#  'Lacoste_Chaymon_Casual_Shoes',
#  'Nike_Shox_Nz_Running_Shoes',
#  'Nike_Air_Force_270_Utility_Off_Court_Shoes']

# %%
np.shape(product_new_name)
# Out:
# (1170,)

# %%
print(product_new_name)
# Out:
# ['Reebok_Classic_Leather_Gum_Casual_Shoes', 'Adidas_Originals_Pod_S31_Casual_Shoes', 'Lacoste_Chaymon_Casual_Shoes', 'Nike_Shox_Nz_Running_Shoes', 'Nike_Air_Force_270_Utility_Off_Court_Shoes', 'Adidas_Originals_Xplr_Casual_Shoes', 'Unisex_Converse_Chuck_Taylor_All_Star_70_High_Top_Casual_Shoes', 'Nike_Free_Rn_Flyknit_2018_Running_Shoes', 'Adidas_Upath_Run_Running_Shoes', 'Air_Jordan_Executive_Off_Court_Shoes', 'Nike_Huarache_Edge_Txt_Running_Shoes', 'Timberland_Philadelphia_76ers_Nba_Field_Boots', 'Air_Jordan_Why_Not_Zer02_Basketball_Shoes', 'Fila_Ray_Tracer_Casual_Shoes', 'Nike_React_Element_55_Casual_Shoes', 'Reebok_Dmx_Series_1600_Casual_Shoes', 'Nike_Air_Force_1_07_Lv8_Style_Casual_Shoes', 'Adidas_Originals_Pod_S31_Casual_Shoes', 'Nike_Air_Max_90_Essential_Casual_Shoes', 'Adidas_Zx_Flux_Casual_Shoes', 'Adidas_Ultraboost_St_Running_Shoes', 'Under_Armour_Hovr_Phantom_Se_Running_Shoes', 'Adidas_Pro_Vision_Select_Player_Edition_Basketball_Shoes', 'Nike_Kawa_Slide_Sandals', 'Nike_Benassi_Jdi_Slide_Sandals', 'Nike_Free_Rn_2018_Running_Shoes', 'Puma_Cell_Venom_Running_Shoes', 'Adidas_Questar_Trail_Running_Shoes', 'Nike_Air_Max_270_Casual_Shoes', 'Nike_Classic_Cortez_Premium_Casual_Shoes', 'Under_Armour_Hovr_Slk_Evo_Running_Shoes', 'Air_Jordan_Retro_1_Low_Basketball_Shoes', 'Nike_Air_Max_270_Se_Reflective_Casual_Shoes', 'Adidas_Duramo_9_Running_Shoes', 'Air_Jordan_1_Mid_Retro_Basketball_Shoes', 'Nike_Odyssey_React_Flyknit_2_Running_Shoes', 'Nike_Cortez_Basic_Floral_Casual_Shoes', 'New_Balance_990_V4_Mid_Running_Shoes', 'Nike_Vapormax_Gliese_Casual_Shoes', 'Under_Armour_Hovr_Infinite_Running_Shoes', 'Under_Armour_Hovr_Sonic_2_Running_Shoes', 'Reebok_Split_Fuel_Casual_Shoes', 'Nike_Benassi_Jdi_Se_Slide_Sandals', 'Puma_Super_Levitate_Running_Shoes', 'Nike_Pegasus_35_Turbo_Running_Shoes', 'Adidas_Upath_Run_Running_Shoes', 'Nike_Air_Force_1_07_Lv8_3_Casual_Shoes', 'Jordan_Break_Slide_Sandals', 'Nike_Air_Huarache_Run_Casual_Shoes', 'Nike_Air_Max_97_Qs_Casual_Shoes', 'Adidas_Harden_Vol3_Basketball_Shoes', 'New_Balance_X_90_V2_Casual_Shoes', 'Adidas_Ultraboost_19_Running_Shoes', 'Nike_Air_Vapormax_Flyknit_2_Running_Shoes', 'Nike_Air_Flightposite_Basketball_Shoes', 'Adidas_Nmd_Runner_R1_Casual_Shoes', 'Nike_Air_Max_Deluxe_Casual_Shoes', 'Champion_Ipo_Chenille_Slide_Sandals', 'Nike_Air_Zoom_Pegasus_35_Running_Shoes', 'Nike_Md_Runner_2019_Casual_Shoes', 'Nike_Air_Max_95_Essential_Casual_Shoes', 'Champion_Ipo_Slide_Sandals', 'Nike_Metcon_Sport_Training_Shoes', 'Puma_Suede_Classic_Casual_Shoes', 'Adidas_Harden_Vol3_Basketball_Shoes', 'Nike_Air_Vapormax_Flyknit_2_Running_Shoes', 'Nike_Cortez_Basic_Leather_Casual_Shoes', 'Reebok_3d_Op_Lite_Casual_Shoes', 'Nike_Air_Darwin_Basketball_Shoes', 'New_Balance_501_Gum_Ripple_Casual_Shoes', 'Nike_Air_Max_Penny_Basketball_Shoes', 'New_Balance_X_90_V2_Casual_Shoes', 'Nike_Air_Max_270_Bowfin_Casual_Shoes', 'Jordan_89_Racer_Running_Shoes', 'Nike_Lebron_Soldier_12_Sfg_Basketball_Shoes', 'Adidas_Adizero_Adios_4_Running_Shoes', 'Puma_Cell_Venom_Running_Shoes', 'Nike_Air_Force_1_High_07_Lv8_1_Casual_Shoes', 'Nike_Air_Max_95_Casual_Shoes', 'Nike_Air_Max_97_Premium_Casual_Shoes', 'Lacoste_Marina_Casual_Shoes', 'Air_Jordan_Jumpman_Hustle_Basketball_Shoes', 'Adidas_Originals_Deerupt_Runner_Casual_Shoes', 'Nike_Kawa_Shower_Marble_Slide_Sandals', 'Adidas_Purebounce_Running_Shoes', 'Jordan_88_Racer_Running_Shoes', 'New_Balance_608_V1_Casual_Shoes', 'Timberland_Cityforce_Reveal_Leather_Boots', 'Adidas_Nmd_Runner_R1_Casual_Shoes', 'Fila_Drifter_Slide_Sandals', 'Jordan_Grind_2_Florida_Gators_Running_Shoes', 'Adidas_Nmd_Runner_R1_Casual_Shoes', 'New_Balance_574_Mid_Casual_Shoes', 'Snkr_Project_Crosby_Casual_Shoes', 'Nike_Air_Force_1_07_Casual_Shoes', 'Nike_Air_Max_Deluxe_Casual_Shoes', 'Asics_Gel_Kayano_25_Running_Shoes', 'Puma_Rs_X_Reinvention_Running_Shoes', 'Nike_Epic_Phantom_React_Flyknit_Running_Shoes', 'Nike_Zoom_2k_Casual_Shoes', 'Adidas_Terrex_Free_Hiker_Outdoor_Sneaker_Boot', 'New_Balance_801_Casual_Shoes', 'Under ...

# %%
with open ("J:/review_star_title.txt", 'w', encoding='utf-8') as f:
    description_list = []
    jishu = 0
    for name in product_new_name:
        for index in range(1, 1000):
            browser = webdriver.Firefox()
            browser_name = "https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_" + str(name) + \
            "/reviews.djs?format=embeddedhtml&page="+ str(index) +"&scrollToTop=true"
            print(browser_name)
            browser.get(browser_name)
            time.sleep(0.99)
            bs_obj = BS(browser.page_source.encode('utf-8', 'ignore'), "html.parser")
            description = bs_obj.get_text()
            star_begin = description.split("BVRRReviewTextContainer")[0]
            description = description.split("BVRRReviewTextContainer")[1:]
            
            for content in description:
                reviews_list = []
                star_list = []
                title_list = []
                first_star_temp = star_begin.split("BVImgOrSprite")[4]
                first_star = first_star_temp.split("reviewRating")[0]
                if "BVRRValue BVRRReviewTitle" in star_begin:
                    first_title_temp = star_begin.split("BVRRReviewTitleContainer")[1]
                    first_title = first_title_temp.split("BVRRLabel BVRRReviewTitleSuffix")[0]

                star_list.append(first_star)
                if "BVImgOrSprite" in content:
                    star_temp = content.split("BVImgOrSprite")[1]
                    star = star_temp.split("reviewRating")[0]
                    star_list.append(star)

                title_list.append(first_title)
                if "BVRRValue BVRRReviewTitle" in content:
                    title_temp = content.split("BVRRValue BVRRReviewTitle")[1]
                    title = title_temp.split("BVRRLabel BVRRReviewTitleSuffix")[0]
                    title_list.append(title)

                reviews_temp = content.split("BVRRReviewTextPrefix")[1]
                reviews = reviews_temp.split("BVRRReviewTextSuffix")[0]
                reviews_list.append(reviews)
#                 print(reviews_list)
                    
                f.write(name + "+-++++++++++++++++++++++++++++++" + \
                        "".join(star_list) + "+++++++++++++++++++++++++++++++" + \
                        "".join(title_list) + "-+-+++++++++++++++++++++++++++++++++++++++" + \
                        "".join(reviews_list))
                f.write('\n')
                f.write("****************************************************************************************")
                f.write('\n')
                f.flush()
            jishu += 1
            browser.quit()
#             print(reviews_list)
            description_list.append(reviews_list)
            print(jishu)
#             print(description_list[jishu-1])
            if index >= 2 and description_list[jishu-2] == reviews_list:
                break
        f.write('\n')
        f.write("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
        f.write('\n')
        f.flush()
# Out:
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Reebok_Classic_Leather_Gum_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 1
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Reebok_Classic_Leather_Gum_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 2
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Pod_S31_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 3
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Pod_S31_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Lacoste_Chaymon_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 5
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Lacoste_Chaymon_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 6
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 7
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 8
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 9
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 10
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 11
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 12
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 13
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 14
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 15
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 16
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 17
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 18
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 19
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 20
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 21
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 22
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 23
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 24
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 25
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 26
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 27
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 28
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 29
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Shox_Nz_Running_Shoes/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 30
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_270_Utility_Off_Court_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 31
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_270_Utility_Off_Court_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 32
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Xplr_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 33
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Xplr_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 34
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Unisex_Converse_Chuck_Taylor_All_Star_70_High_Top_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 35
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Unisex_Converse_Chuck_Taylor_All_Star_70_High_Top_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 36
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 37
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 38
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 39
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 40
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 41
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 42
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_Flyknit_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 43
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Upath_Run_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 44
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Upath_Run_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 45
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Executive_Off_Court_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 46
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Executive_Off_Court_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 47
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Huarache_Edge_Txt_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 48
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Huarache_Edge_Txt_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 49
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Timberland_Philadelphia_76ers_Nba_Field_Boots/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 50
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Timberland_Philadelphia_76ers_Nba_Field_Boots/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 51
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Why_Not_Zer02_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 52
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Why_Not_Zer02_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 53
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Fila_Ray_Tracer_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 54
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Fila_Ray_Tracer_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 55
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_React_Element_55_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 56
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_React_Element_55_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 57
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_React_Element_55_Casual_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 58
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_React_Element_55_Casual_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 59
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_React_Element_55_Casual_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 60
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Reebok_Dmx_Series_1600_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 61
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Reebok_Dmx_Series_1600_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 62
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_07_Lv8_Style_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 63
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_07_Lv8_Style_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 64
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Pod_S31_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 65
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Originals_Pod_S31_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 66
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 67
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 68
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 69
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 70
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 71
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 72
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 73
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 74
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 75
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 76
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 77
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 78
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 79
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 80
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 81
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 82
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 83
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 84
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 85
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 86
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 87
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 88
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 89
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 90
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=25&scrollToTop=true
# 91
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=26&scrollToTop=true
# 92
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=27&scrollToTop=true
# 93
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=28&scrollToTop=true
# 94
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=29&scrollToTop=true
# 95
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=30&scrollToTop=true
# 96
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=31&scrollToTop=true
# 97
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=32&scrollToTop=true
# 98
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=33&scrollToTop=true
# 99
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=34&scrollToTop=true
# 100
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=35&scrollToTop=true
# 101
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=36&scrollToTop=true
# 102
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=37&scrollToTop=true
# 103
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=38&scrollToTop=true
# 104
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=39&scrollToTop=true
# 105
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=40&scrollToTop=true
# 106
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=41&scrollToTop=true
# 107
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=42&scrollToTop=true
# 108
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=43&scrollToTop=true
# 109
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=44&scrollToTop=true
# 110
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=45&scrollToTop=true
# 111
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=46&scrollToTop=true
# 112
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=47&scrollToTop=true
# 113
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=48&scrollToTop=true
# 114
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=49&scrollToTop=true
# 115
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_90_Essential_Casual_Shoes/reviews.djs?format=embeddedhtml&page=50&scrollToTop=true
# 116
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 117
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 118
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 119
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 120
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 121
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 122
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 123
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 124
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 125
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 126
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 127
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 128
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 129
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 130
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 131
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 132
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 133
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 134
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 135
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 136
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Zx_Flux_Casual_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 137
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 138
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 139
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 140
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 141
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 142
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 143
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 144
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 145
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 146
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 147
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 148
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 149
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 150
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 151
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 152
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 153
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 154
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 155
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 156
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 157
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 158
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 159
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 160
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 161
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=25&scrollToTop=true
# 162
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=26&scrollToTop=true
# 163
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=27&scrollToTop=true
# 164
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=28&scrollToTop=true
# 165
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=29&scrollToTop=true
# 166
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=30&scrollToTop=true
# 167
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=31&scrollToTop=true
# 168
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Ultraboost_St_Running_Shoes/reviews.djs?format=embeddedhtml&page=32&scrollToTop=true
# 169
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Phantom_Se_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 170
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Phantom_Se_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 171
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Phantom_Se_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 172
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Phantom_Se_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 173
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Pro_Vision_Select_Player_Edition_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 174
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Pro_Vision_Select_Player_Edition_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 175
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Kawa_Slide_Sandals/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 176
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Kawa_Slide_Sandals/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 177
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Kawa_Slide_Sandals/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 178
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 179
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 180
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 181
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 182
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 183
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 184
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 185
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 186
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 187
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 188
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 189
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 190
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 191
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 192
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 193
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 194
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 195
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 196
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 197
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 198
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 199
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 200
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 201
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 202
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=25&scrollToTop=true
# 203
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=26&scrollToTop=true
# 204
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=27&scrollToTop=true
# 205
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=28&scrollToTop=true
# 206
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=29&scrollToTop=true
# 207
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=30&scrollToTop=true
# 208
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=31&scrollToTop=true
# 209
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=32&scrollToTop=true
# 210
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=33&scrollToTop=true
# 211
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=34&scrollToTop=true
# 212
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Benassi_Jdi_Slide_Sandals/reviews.djs?format=embeddedhtml&page=35&scrollToTop=true
# 213
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 214
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 215
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 216
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 217
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 218
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 219
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Free_Rn_2018_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 220
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Puma_Cell_Venom_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 221
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Puma_Cell_Venom_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 222
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Questar_Trail_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 223
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Questar_Trail_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 224
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 225
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 226
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 227
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 228
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 229
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 230
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 231
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 232
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 233
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 234
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 235
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 236
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 237
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 238
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 239
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 240
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 241
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 242
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Casual_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 243
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Classic_Cortez_Premium_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 244
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Classic_Cortez_Premium_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 245
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Slk_Evo_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 246
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Slk_Evo_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 247
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 248
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 249
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 250
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 251
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 252
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 253
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 254
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 255
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 256
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 257
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 258
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 259
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 260
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 261
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 262
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 263
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 264
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 265
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 266
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 267
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 268
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 269
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 270
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 271
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=25&scrollToTop=true
# 272
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=26&scrollToTop=true
# 273
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=27&scrollToTop=true
# 274
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=28&scrollToTop=true
# 275
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=29&scrollToTop=true
# 276
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=30&scrollToTop=true
# 277
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=31&scrollToTop=true
# 278
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=32&scrollToTop=true
# 279
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=33&scrollToTop=true
# 280
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=34&scrollToTop=true
# 281
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=35&scrollToTop=true
# 282
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=36&scrollToTop=true
# 283
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=37&scrollToTop=true
# 284
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=38&scrollToTop=true
# 285
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=39&scrollToTop=true
# 286
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=40&scrollToTop=true
# 287
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Air_Jordan_Retro_1_Low_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=41&scrollToTop=true
# 288
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Se_Reflective_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 289
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Max_270_Se_Reflective_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 290
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 291
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 292
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 293
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 294
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 295
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 296
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 297
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 298
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 299
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 300
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 301
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 302
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 303
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 304
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 305
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 306
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 307
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=18&scrollToTop=true
# 308
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=19&scrollToTop=true
# 309
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=20&scrollToTop=true
# 310
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=21&scrollToTop=true
# 311
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=22&scrollToTop=true
# 312
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=23&scrollToTop=true
# 313
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=24&scrollToTop=true
# 314
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Duramo_9_Running_Shoes/reviews.djs?format=embeddedhtml&page=25&scrollToTop=true
# 315
# ...
# 4159
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=137&scrollToTop=true
# 4160
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=138&scrollToTop=true
# 4161
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=139&scrollToTop=true
# 4162
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=140&scrollToTop=true
# 4163
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=141&scrollToTop=true
# 4164
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=142&scrollToTop=true
# 4165
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=143&scrollToTop=true
# 4166
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=144&scrollToTop=true
# 4167
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=145&scrollToTop=true
# 4168
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=146&scrollToTop=true
# 4169
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=147&scrollToTop=true
# 4170
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=148&scrollToTop=true
# 4171
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=149&scrollToTop=true
# 4172
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=150&scrollToTop=true
# 4173
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=151&scrollToTop=true
# 4174
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=152&scrollToTop=true
# 4175
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=153&scrollToTop=true
# 4176
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=154&scrollToTop=true
# 4177
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=155&scrollToTop=true
# 4178
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=156&scrollToTop=true
# 4179
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=157&scrollToTop=true
# 4180
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=158&scrollToTop=true
# 4181
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=159&scrollToTop=true
# 4182
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=160&scrollToTop=true
# 4183
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=161&scrollToTop=true
# 4184
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=162&scrollToTop=true
# 4185
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=163&scrollToTop=true
# 4186
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=164&scrollToTop=true
# 4187
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=165&scrollToTop=true
# 4188
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=166&scrollToTop=true
# 4189
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=167&scrollToTop=true
# 4190
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=168&scrollToTop=true
# 4191
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=169&scrollToTop=true
# 4192
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=170&scrollToTop=true
# 4193
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Nmd_R2_Casual_Shoes/reviews.djs?format=embeddedhtml&page=171&scrollToTop=true
# 4194
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Puma_Rs_X_Tracks_Mtv_Gradient_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4195
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Puma_Rs_X_Tracks_Mtv_Gradient_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4196
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4197
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4198
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 4199
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 4200
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 4201
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 4202
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 4203
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Dame_5_Basketball_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 4204
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_Utility_Mid_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4205
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_Utility_Mid_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4206
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4207
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4208
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 4209
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 4210
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 4211
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 4212
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 4213
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 4214
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 4215
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=10&scrollToTop=true
# 4216
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=11&scrollToTop=true
# 4217
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=12&scrollToTop=true
# 4218
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=13&scrollToTop=true
# 4219
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=14&scrollToTop=true
# 4220
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=15&scrollToTop=true
# 4221
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=16&scrollToTop=true
# 4222
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Flyknit_2_Running_Shoes/reviews.djs?format=embeddedhtml&page=17&scrollToTop=true
# 4223
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Converse_Courlandt_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4224
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Converse_Courlandt_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4225
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Metcon_Sport_Training_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4226
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Metcon_Sport_Training_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4227
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4228
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4229
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 4230
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 4231
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 4232
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 4233
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=7&scrollToTop=true
# 4234
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=8&scrollToTop=true
# 4235
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_New_Balance_574_Casual_Shoes/reviews.djs?format=embeddedhtml&page=9&scrollToTop=true
# 4236
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_K_Swiss_St329_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4237
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_K_Swiss_St329_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4238
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Champion_93eighteen_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4239
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Champion_93eighteen_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4240
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Asics_Gel_Kayano_5_Og_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4241
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Asics_Gel_Kayano_5_Og_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4242
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4243
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4244
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 4245
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 4246
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 4247
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Zoom_Fly_Flyknit_Running_Shoes/reviews.djs?format=embeddedhtml&page=6&scrollToTop=true
# 4248
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Adizero_Burner_Football_Cleats/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4249
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Adizero_Burner_Football_Cleats/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4250
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_07_Lv8_Style_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4251
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Force_1_07_Lv8_Style_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4252
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Plus_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4253
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Plus_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4254
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Plus_Running_Shoes/reviews.djs?format=embeddedhtml&page=3&scrollToTop=true
# 4255
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Plus_Running_Shoes/reviews.djs?format=embeddedhtml&page=4&scrollToTop=true
# 4256
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Nike_Air_Vapormax_Plus_Running_Shoes/reviews.djs?format=embeddedhtml&page=5&scrollToTop=true
# 4257
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Champion_93eighteen_Casual_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4258
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Champion_93eighteen_Casual_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4259
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Slk_Evo_Running_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4260
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Under_Armour_Hovr_Slk_Evo_Running_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4261
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Predator_193_Indoor_Soccer_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4262
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Predator_193_Indoor_Soccer_Shoes/reviews.djs?format=embeddedhtml&page=2&scrollToTop=true
# 4263
# https://finishline.ugc.bazaarvoice.com/9345/Men_char39_s_Adidas_Leistung16_Ii_Training_Shoes/reviews.djs?format=embeddedhtml&page=1&scrollToTop=true
# 4264

# %%
driver = webdriver.Firefox(executable_path=r'E:/firefoxdriver/geckodriver.exe', log_path='./Log/geckodriver.log')
driver.get('https://www.google.co.in')
print("Page Title is : %s" %driver.title)
driver.quit()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use service_log_path instead of log_path
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-103-d66485a0d0cf> in <module>
# ----> 1 driver = webdriver.Firefox(executable_path=r'E:/firefoxdriver/geckodriver.exe', log_path='./Log/geckodriver.log')
#       2 driver.get('https://www.google.co.in')
#       3 print("Page Title is : %s" %driver.title)
#       4 driver.quit()
#
# C:\Anaconda\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     161                 executable_path,
#     162                 service_args=service_args,
# --> 163                 log_path=service_log_path)
#     164             self.service.start()
#     165
#
# C:\Anaconda\lib\site-packages\selenium\webdriver\firefox\service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      42
#      43         """
# ---> 44         log_file = open(log_path, "a+") if log_path is not None and log_path != "" else None
#      45
#      46         service.Service.__init__(
#
# FileNotFoundError: [Errno 2] No such file or directory: './Log/geckodriver.log'

# %%
l = [[1], [2], [3]]
n = [[3], [2], [1]]
if l == n:
    print("yes")

# %%
with open ("J:/reviews.txt", 'a', encoding='utf-8') as f:
    for name in [product_new_name]:
        options = Options()
        options.add_argument("start-maximized")
        browser = webdriver.Chrome(chrome_options = options)
        print(url)
        browser_name = "https://www.finishline.com" + url
        browser.get(browser_name)
        time.sleep(2)
        bs_obj = BS(browser.page_source.encode('utf-8', 'ignore'), "html.parser")
        description = bs_obj.findAll("div", {"class":"BVRRReviewTextParagraph BVRRReviewTextFirstParagraph BVRRReviewTextLastParagraph"})  
        for i in description:
        #       print(i.find_all("li"))
#                 product_name_description[product_name] = [i.find_all("li")]
            details = "".join(i.stripped_strings)
            f.write(product_name + "===" + repr(details))
            f.write('\n')
            f.flush()
            browser.quit()
